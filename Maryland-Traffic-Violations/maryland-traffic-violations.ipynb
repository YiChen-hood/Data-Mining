# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/traffic-violations-in-maryland-county/Traffic_Violations.csv

# %%
df.columns
# Out:
# Index(['Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency', 'Description',
#        'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone', 'State',
#        'VehicleType', 'Year', 'Make', 'Model', 'Color', 'Violation Type',
#        'Charge', 'Article', 'Contributed To Accident', 'Race', 'Gender',
#        'Driver City', 'Driver State', 'DL State', 'Arrest Type',
#        'Geolocation'],
#       dtype='object')

# %%
df['Color'].value_counts()[:8].plot(kind='barh')

# %%
df['Model'].value_counts()[:8].plot(kind='barh')

# %%
df['Make'].value_counts()[:8].plot(kind='barh')

# %%
df['Gender'].value_counts()[:2].plot(kind='barh')

# %%
df['Location'].value_counts()[:8].plot(kind='barh')

# %%
df['Race'].value_counts()[:8].plot(kind='barh')

# %%
df['Arrest Type'].value_counts()[:8].plot(kind='barh')

# %%
df['Contributed To Accident'].value_counts()[:2].plot(kind='barh')

# %%
df['Belts'].value_counts()[:2].plot(kind='barh')

# %%
df['Fatal'].value_counts()[:2].plot(kind='barh')

# %%
df['Alcohol'].value_counts()[:2].plot(kind='barh')

# %%
df['State'].value_counts()[:8].plot(kind='barh')

# %%
df.tail(8)
# Out:
#         Date Of Stop Time Of Stop Agency                            SubAgency  \
# 1292391   12/14/2012     23:20:00    MCP  Headquarters and Special Operations
# 1292392   12/14/2012     23:33:00    MCP  Headquarters and Special Operations
# 1292393   12/14/2012     23:42:00    MCP  Headquarters and Special Operations
# 1292394   12/14/2012     23:56:00    MCP  Headquarters and Special Operations
# 1292395   12/15/2012     00:11:00    MCP  Headquarters and Special Operations
# 1292396   12/15/2012     00:30:00    MCP  Headquarters and Special Operations
# 1292397   12/16/2012     22:55:00    MCP  Headquarters and Special Operations
# 1292398   12/21/2012     23:47:00    MCP  Headquarters and Special Operations
#
#          Description                       Location   Latitude  Longitude  \
# 1292391  Stop Lights        MD 355/ PROFESSIONAL DR  39.162066 -77.224062
# 1292392   Tag Lights               MVA/ RUSSELL AVE  39.154323 -77.209751
# ...

# %%
df.head(8)
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 0   09/24/2013     17:11:00    MCP
# 1   08/29/2017     10:19:00    MCP
# 2   12/01/2014     12:52:00    MCP
# 3   08/29/2017     09:22:00    MCP
# 4   08/28/2017     23:41:00    MCP
# 5   08/27/2013     00:55:00    MCP
# 6   10/08/2013     13:23:00    MCP
# 7   04/24/2015     00:38:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2  6th district, Gaithersburg / Montgomery Village
# 3                      3rd district, Silver Spring
# 4  6th district, Gaithersburg / Montgomery Village
# 5                           2nd district, Bethesda
# 6                            4th district, Wheaton
# 7                          1st district, Rockville
#
#                                          Description  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# ...

# %%
df.shape
# Out:
# (1292399, 35)
